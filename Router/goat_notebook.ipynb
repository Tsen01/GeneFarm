# %%
# %pip install fastapi python-dotenv uvicorn nest_asyncio
# %pip install Jinja2
# %pip install tensorflow
# %pip install python-multipart
# Out:
# Requirement already satisfied: fastapi in /home/project/projectdata/.venv/lib/python3.12/site-packages (0.115.12)
# Requirement already satisfied: python-dotenv in /home/project/projectdata/.venv/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: uvicorn in /home/project/projectdata/.venv/lib/python3.12/site-packages (0.34.2)
# Requirement already satisfied: nest_asyncio in /home/project/projectdata/.venv/lib/python3.12/site-packages (1.6.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from fastapi) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from fastapi) (2.11.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from fastapi) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: click>=7.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from uvicorn) (0.16.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Jinja2 in /home/project/projectdata/.venv/lib/python3.12/site-packages (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from Jinja2) (3.0.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in /home/project/projectdata/.venv/lib/python3.12/site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (80.4.0)
# Requirement already satisfied: six>=1.12.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /home/project/projectdata/.venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /home/project/projectdata/.venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /home/project/projectdata/.venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-multipart in /home/project/projectdata/.venv/lib/python3.12/site-packages (0.0.20)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install flask
# Out:
# Requirement already satisfied: flask in /home/project/projectdata/.venv/lib/python3.12/site-packages (3.1.2)
# Requirement already satisfied: blinker>=1.9.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from flask) (8.1.8)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from flask) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/project/projectdata/.venv/lib/python3.12/site-packages (from flask) (3.1.3)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import uvicorn
import nest_asyncio
from threading import Thread

# 允許 Jupyter 重複使用事件 loop
nest_asyncio.apply()

def run_app():
    # 移除 reload=True，避免 signal 問題
    uvicorn.run("main:app", host="127.0.0.1", port=8000)
    # uvicorn.run("main:app", host="127.0.0.1", port=8000, reload=True)

# 使用 Thread 非同步啟動 FastAPI
server_thread = Thread(target=run_app, daemon=True)
server_thread.start()
# Out:
# 2025-11-06 03:32:48.887921: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-06 03:32:48.895074: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762399968.903531 1232624 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762399968.906131 1232624 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762399968.912847 1232624 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762399968.912854 1232624 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762399968.912855 1232624 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762399968.912856 1232624 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-06 03:32:48.915522: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:     Started server process [1232610]
# INFO:     Waiting for application startup.
# SSH_HOST: 140.127.22.195
# MONGO_HOST: localhost
# ALLOWED_ORIGINS: http://localhost,http://127.0.0.1,http://127.0.0.1:8000
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# 🔗 MongoDB 連線已建立
# INFO:     127.0.0.1:41014 - "GET / HTTP/1.1" 302 Found
# INFO:     127.0.0.1:41014 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41014 - "GET /static/js/auth.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41026 - "GET /static/js/ForgotPW.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41042 - "GET /static/img/background.png HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41014 - "GET /static/js/loadCollection.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41026 - "GET /static/js/localStorage.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41042 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:41042 - "GET /AnimalManager/gene HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41026 - "GET /static/js/loadGene.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41014 - "GET /static/img/addGene.png HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41042 - "GET /static/css/format.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41026 - "GET /gene/collections HTTP/1.1" 401 Unauthorized
# INFO:     127.0.0.1:41026 - "GET /AnimalManager/genePredict HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41026 - "GET /static/css/predict.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41042 - "GET /static/js/genePredict.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41014 - "GET /static/js/addCollection.js HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:41014 - "GET /AnimalManager/history HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41014 - "GET /static/js/history.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41014 - "POST /get_personal_data HTTP/1.1" 401 Unauthorized
# INFO:     127.0.0.1:41014 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41014 - "GET /AnimalManager/history HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41014 - "POST /get_personal_data HTTP/1.1" 401 Unauthorized
# INFO:     127.0.0.1:41014 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41014 - "GET /AnimalManager HTTP/1.1" 200 OK
# 成功連線到 goat_project
# 解析登入資料: email='test@01.com' password='1'
# user = {'_id': ObjectId('689eaad86a44fa4bdbf812a4'), 'username': 'test01', 'email': 'test@01.com', 'password': '$2b$12$c..Lkiou1QNbgseUyNcHGe7xKAsmmiUylK160vRMDsn/nMxn7UW3m', 'role': 'GeneticResearcher', 'user_id': '6a79724b-815d-42ec-92db-0193f4b3fee7'}
# INFO:     127.0.0.1:59344 - "POST /auth/login HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "GET /AnimalManager/gene HTTP/1.1" 200 OK
# Token payload:  {'sub': '6a79724b-815d-42ec-92db-0193f4b3fee7', 'username': 'test01', 'role': 'GeneticResearcher', 'email': 'test@01.com', 'exp': 1762403590}
# INFO:     127.0.0.1:59344 - "GET /gene/collections HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "GET /AnimalManager/genePredict HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "GET /static/js/addCollection.js HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:59344 - "GET /AnimalManager/history HTTP/1.1" 200 OK
# Token payload:  {'sub': '6a79724b-815d-42ec-92db-0193f4b3fee7', 'username': 'test01', 'role': 'GeneticResearcher', 'email': 'test@01.com', 'exp': 1762403590}
# INFO:     127.0.0.1:59344 - "POST /get_personal_data HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "GET /AnimalManager/gene HTTP/1.1" 200 OK
# Token payload:  {'sub': '6a79724b-815d-42ec-92db-0193f4b3fee7', 'username': 'test01', 'role': 'GeneticResearcher', 'email': 'test@01.com', 'exp': 1762403590}
# INFO:     127.0.0.1:59344 - "GET /gene/collections HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "GET /AnimalManager/genePredict HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "GET /static/js/addCollection.js HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:59344 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33114 - "GET /AnimalManager HTTP/1.1" 200 OK
# 成功連線到 goat_project
# 解析登入資料: email='test@02.com' password='2'
# user = {'_id': ObjectId('689eaf486a44fa4bdbf812a5'), 'username': 'test02', 'email': 'test@02.com', 'password': '$2b$12$hebC8HcceHvDug4pW9jEZOPd3Tpz6kEVwrXX5hD3EumMWq0JCpfBS', 'role': 'Farmer', 'user_id': '4d11c1de-72de-4ac3-aa4b-3d2918f75985'}
# INFO:     127.0.0.1:33114 - "POST /auth/login HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33114 - "GET /AnimalManager/myfarm HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33114 - "GET /static/img/addCollection.png HTTP/1.1" 200 OK
# Token payload:  {'sub': '4d11c1de-72de-4ac3-aa4b-3d2918f75985', 'username': 'test02', 'role': 'Farmer', 'email': 'test@02.com', 'exp': 1762403621}
# INFO:     127.0.0.1:56162 - "GET /farm/collections HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56162 - "GET /AnimalManager/predict HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33114 - "GET /static/js/predict.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56162 - "GET /static/img/goat.png HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56162 - "GET /AnimalManager/history HTTP/1.1" 200 OK
# Token payload:  {'sub': '4d11c1de-72de-4ac3-aa4b-3d2918f75985', 'username': 'test02', 'role': 'Farmer', 'email': 'test@02.com', 'exp': 1762403621}
# INFO:     127.0.0.1:56162 - "POST /get_personal_data HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56162 - "GET /AnimalManager/predict HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56162 - "GET /get_sheep_list HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52674 - "GET /AnimalManager/myfarm HTTP/1.1" 200 OK
# Token payload:  {'sub': '4d11c1de-72de-4ac3-aa4b-3d2918f75985', 'username': 'test02', 'role': 'Farmer', 'email': 'test@02.com', 'exp': 1762403621}
# INFO:     127.0.0.1:52674 - "GET /farm/collections HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52674 - "GET /AnimalManager/predict HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52674 - "GET /AnimalManager/myfarm HTTP/1.1" 200 OK
# Token payload:  {'sub': '4d11c1de-72de-4ac3-aa4b-3d2918f75985', 'username': 'test02', 'role': 'Farmer', 'email': 'test@02.com', 'exp': 1762403621}
# INFO:     127.0.0.1:52674 - "GET /farm/collections HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40548 - "GET /AnimalManager/history HTTP/1.1" 200 OK
# Token payload:  {'sub': '4d11c1de-72de-4ac3-aa4b-3d2918f75985', 'username': 'test02', 'role': 'Farmer', 'email': 'test@02.com', 'exp': 1762403621}
# INFO:     127.0.0.1:40548 - "POST /get_personal_data HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40548 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40548 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:40548 - "GET /AnimalManager HTTP/1.1" 200 OK
# 成功連線到 goat_project
# 解析登入資料: email='test@02.com' password='2'
# user = {'_id': ObjectId('689eaf486a44fa4bdbf812a5'), 'username': 'test02', 'email': 'test@02.com', 'password': '$2b$12$hebC8HcceHvDug4pW9jEZOPd3Tpz6kEVwrXX5hD3EumMWq0JCpfBS', 'role': 'Farmer', 'user_id': '4d11c1de-72de-4ac3-aa4b-3d2918f75985'}
# INFO:     127.0.0.1:46970 - "POST /auth/login HTTP/1.1" 200 OK
# INFO:     127.0.0.1:46970 - "GET /AnimalManager/myfarm HTTP/1.1" 200 OK
# Token payload:  {'sub': '4d11c1de-72de-4ac3-aa4b-3d2918f75985', 'username': 'test02', 'role': 'Farmer', 'email': 'test@02.com', 'exp': 1762403720}
# INFO:     127.0.0.1:46970 - "GET /farm/collections HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49144 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:43328 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36530 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36530 - "GET /static/js/auth.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36538 - "GET /static/js/ForgotPW.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36552 - "GET /static/img/background.png HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36530 - "GET /static/js/loadCollection.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36538 - "GET /static/js/localStorage.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36552 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:35598 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39724 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:48100 - "GET /AnimalManager HTTP/1.1" 200 OK
# 成功連線到 goat_project
# 解析登入資料: email='test@02.com' password='2'
# user = {'_id': ObjectId('689eaf486a44fa4bdbf812a5'), 'username': 'test02', 'email': 'test@02.com', 'password': '$2b$12$hebC8HcceHvDug4pW9jEZOPd3Tpz6kEVwrXX5hD3EumMWq0JCpfBS', 'role': 'Farmer', 'user_id': '4d11c1de-72de-4ac3-aa4b-3d2918f75985'}
# INFO:     127.0.0.1:39672 - "POST /auth/login HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39672 - "GET /AnimalManager/myfarm HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39672 - "GET /static/css/format.css HTTP/1.1" 200 OK
# Token payload:  {'sub': '4d11c1de-72de-4ac3-aa4b-3d2918f75985', 'username': 'test02', 'role': 'Farmer', 'email': 'test@02.com', 'exp': 1762410833}
# INFO:     127.0.0.1:39672 - "GET /farm/collections HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39684 - "GET /static/img/addCollection.png HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39684 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56108 - "GET /AnimalManager HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55522 - "GET /AnimalManager HTTP/1.1" 200 OK

# %%
import tensorflow as tf
print(tf.config.list_physical_devices("GPU"))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf
print(tf.sysconfig.get_build_info()["cuda_version"])
print(tf.sysconfig.get_build_info()["cudnn_version"])
# Out:
# 12.5.1
# 9

# %%
import tensorflow as tf
with tf.device("/GPU:0"):
    a = tf.random.uniform((1000, 1000))
    b = tf.random.uniform((1000, 1000))
    c = tf.matmul(a, b)
print(c)
# Out:
# I0000 00:00:1762398671.076348 1229591 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14273 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9
# tf.Tensor(
# [[263.8593  254.38826 247.81313 ... 245.53867 256.93304 257.7481 ]
#  [257.57248 248.74632 237.6261  ... 236.72572 241.54376 247.61823]
#  [261.82022 249.0294  246.31833 ... 239.93279 251.74222 250.00221]
#  ...
#  [269.4304  260.59106 247.75117 ... 245.6918  248.28087 256.43008]
#  [257.3279  252.9885  248.52728 ... 239.49141 245.62587 247.8893 ]
#  [255.71815 245.51183 233.55171 ... 231.98024 242.77438 243.78284]], shape=(1000, 1000), dtype=float32)

# %%
import tensorflow as tf
print(tf.__version__)
print("GPU Available:", tf.config.list_physical_devices("GPU"))
# Out:
# 2.19.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf

# 建立一個大矩陣乘法來測試 GPU
with tf.device("/GPU:0"):
    a = tf.random.normal([5000, 5000])
    b = tf.random.normal([5000, 5000])
    c = tf.matmul(a, b)

print("c shape:", c.shape)
# Out:
# c shape: (5000, 5000)
